# %%
from keras.models import Sequential
from keras.layers import Conv2D
from keras.layers import MaxPooling2D
from keras.layers import Flatten
from keras.layers import Dense
import numpy as np
import pandas as pd
from sklearn.model_selection import *
from keras.layers import Dense, Dropout, Input, Flatten
from keras import optimizers
from keras.optimizers import Adam
from keras.preprocessing.image import ImageDataGenerator

model=Sequential();

#One block
model.add(Conv2D(64, (3,3), input_shape=(64,64,1), activation="relu"));
model.add(MaxPooling2D((3,3)))

#Block two
model.add(Conv2D(128, (3,3), activation="relu"))
model.add(Conv2D(256, (3,3), activation="relu"))
model.add(MaxPooling2D((3,3)))

#Block three
model.add(Conv2D(256, (3,3), activation="relu"))
model.add(MaxPooling2D((3,3)))

model.add(Flatten())

#Final connections
model.add(Dense(activation="relu", units=256))
model.add(Dropout(0.3))
model.add(Dense(activation="sigmoid", units=1))

model.compile(optimizer="adam", loss="binary_crossentropy", metrics=["accuracy"])
print(model.summary());

#Getting the data
import pandas as pd
dataset=pd.read_csv('/gdrive/My Drive/Colab Notebooks/dogCat/theFinalDataset.csv')
image_array = []
classLabels=[]

for j in range(0, 10000):
 pyString=dataset.iloc[j].tolist()
 classLabels.append(np.array(pyString[0][-1]))
 for index, item in enumerate(pyString):
        # 48x48
        data = np.zeros((64,64), dtype=np.uint8)
        # split space separated ints
        pixel_data = item.split()
        

        # 0 -> 47, loop through the rows
        for i in range(0, 64):
            # (0 = 0), (1 = 47), (2 = 94), ...
            pixel_index = i * 64
            # (0 = [0:47]), (1 = [47: 94]), (2 = [94, 141]), ...
            data[i] = pixel_data[pixel_index:pixel_index + 64]

        normData=[x/255 for x in data]
        image_array.append(np.array(normData))
        
        

image_array = np.array(image_array)
classLabels=np.asarray(classLabels)
classLabels=[int(x) for x in classLabels]

x_train, y_train, x_test, y_test = [], [], [], []
x_train, x_test, y_train, y_test = train_test_split(image_array, classLabels, test_size=0.2, random_state=42)

x_train=x_train.reshape(x_train.shape[0],64,64,1)
x_test=x_test.reshape(x_test.shape[0], 64,64,1)


gen = ImageDataGenerator(featurewise_center=False,
                        featurewise_std_normalization=False,
                        rotation_range=10,
                        width_shift_range=0.1,
                        height_shift_range=0.1,
                        zoom_range=.1,
                        horizontal_flip=True)

train_generator = gen.flow(x_train, y_train, batch_size=128)
history=model.fit_generator(train_generator, steps_per_epoch=128, epochs=70)

train_score = model.evaluate(x_train, y_train, verbose=0)
print('Train loss:', train_score[0])
print('Train accuracy:', 100*train_score[1])
 
test_score = model.evaluate(x_test, y_test, verbose=0)
print('Test loss:', test_score[0])
print('Test accuracy:', 100*test_score[1])
  
'''model_json = model.to_json()
with open("/gdrive/My Drive/Colab Notebooks/dogCat/myMoodModelORIGINAL.json", "w") as json_file:
    json_file.write(model_json)
# serialize weights to HDF5
model.save_weights("/gdrive/My Drive/Colab Notebooks/dogCat/model_weightsORIGINAL.h5")
print("Saved model to drive")'''
# Out:
# Using TensorFlow backend.
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 62, 62, 64)        640
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 20, 20, 64)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 18, 18, 128)       73856
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 16, 16, 256)       295168
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 5, 5, 256)         0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 3, 3, 256)         590080
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 1, 1, 256)         0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 256)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 256)               65792
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 257
# =================================================================
# Total params: 1,025,793
# Trainable params: 1,025,793
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/70
# 128/128 [==============================] - 14s 106ms/step - loss: 0.6878 - accuracy: 0.5333
# Epoch 2/70
# 128/128 [==============================] - 8s 59ms/step - loss: 0.6608 - accuracy: 0.6096
# Epoch 3/70
# 128/128 [==============================] - 8s 59ms/step - loss: 0.6119 - accuracy: 0.6674
# Epoch 4/70
# 128/128 [==============================] - 8s 60ms/step - loss: 0.5573 - accuracy: 0.7151
# Epoch 5/70
# 128/128 [==============================] - 8s 60ms/step - loss: 0.5102 - accuracy: 0.7514
# Epoch 6/70
# 128/128 [==============================] - 8s 61ms/step - loss: 0.4643 - accuracy: 0.7788
# Epoch 7/70
# 128/128 [==============================] - 8s 59ms/step - loss: 0.4369 - accuracy: 0.7965
# Epoch 8/70
# 128/128 [==============================] - 8s 59ms/step - loss: 0.4073 - accuracy: 0.8143
# Epoch 9/70
# 128/128 [==============================] - 8s 60ms/step - loss: 0.3924 - accuracy: 0.8219
# Epoch 10/70
# 128/128 [==============================] - 8s 60ms/step - loss: 0.3790 - accuracy: 0.8296
# Epoch 11/70
# 128/128 [==============================] - 8s 59ms/step - loss: 0.3579 - accuracy: 0.8392
# Epoch 12/70
# 128/128 [==============================] - 8s 60ms/step - loss: 0.3382 - accuracy: 0.8514
# Epoch 13/70
# 128/128 [==============================] - 8s 59ms/step - loss: 0.3358 - accuracy: 0.8497
# Epoch 14/70
# 128/128 [==============================] - 8s 59ms/step - loss: 0.3179 - accuracy: 0.8614
# Epoch 15/70
# 128/128 [==============================] - 8s 60ms/step - loss: 0.3091 - accuracy: 0.8662
# Epoch 16/70
# 128/128 [==============================] - 8s 60ms/step - loss: 0.3039 - accuracy: 0.8661
# Epoch 17/70
# 128/128 [==============================] - 8s 59ms/step - loss: 0.2817 - accuracy: 0.8782
# Epoch 18/70
# 128/128 [==============================] - 8s 59ms/step - loss: 0.2764 - accuracy: 0.8830
# Epoch 19/70
# 128/128 [==============================] - 8s 59ms/step - loss: 0.2764 - accuracy: 0.8764
# Epoch 20/70
# 128/128 [==============================] - 8s 60ms/step - loss: 0.2632 - accuracy: 0.8843
# Epoch 21/70
# 128/128 [==============================] - 8s 59ms/step - loss: 0.2541 - accuracy: 0.8918
# Epoch 22/70
# 128/128 [==============================] - 8s 59ms/step - loss: 0.2353 - accuracy: 0.9017
# Epoch 23/70
# 128/128 [==============================] - 8s 61ms/step - loss: 0.2429 - accuracy: 0.8980
# Epoch 24/70
# 128/128 [==============================] - 8s 61ms/step - loss: 0.2294 - accuracy: 0.9008
# Epoch 25/70
# 128/128 [==============================] - 8s 61ms/step - loss: 0.2247 - accuracy: 0.9035
# Epoch 26/70
# 128/128 [==============================] - 8s 61ms/step - loss: 0.2188 - accuracy: 0.9074
# Epoch 27/70
# 128/128 [==============================] - 8s 59ms/step - loss: 0.2087 - accuracy: 0.9103
# Epoch 28/70
# 128/128 [==============================] - 8s 59ms/step - loss: 0.2134 - accuracy: 0.9090
# Epoch 29/70
# 128/128 [==============================] - 8s 60ms/step - loss: 0.2058 - accuracy: 0.9126
# Epoch 30/70
# 128/128 [==============================] - 8s 59ms/step - loss: 0.2044 - accuracy: 0.9126
# Epoch 31/70
# 128/128 [==============================] - 8s 60ms/step - loss: 0.1908 - accuracy: 0.9211
# Epoch 32/70
# 128/128 [==============================] - 8s 60ms/step - loss: 0.1854 - accuracy: 0.9238
# Epoch 33/70
# 128/128 [==============================] - 8s 60ms/step - loss: 0.1832 - accuracy: 0.9249
# Epoch 34/70
# 128/128 [==============================] - 8s 59ms/step - loss: 0.1758 - accuracy: 0.9273
# Epoch 35/70
# 128/128 [==============================] - 8s 60ms/step - loss: 0.1816 - accuracy: 0.9250
# Epoch 36/70
# 128/128 [==============================] - 8s 61ms/step - loss: 0.1740 - accuracy: 0.9285
# Epoch 37/70
# 128/128 [==============================] - 8s 60ms/step - loss: 0.1679 - accuracy: 0.9306
# Epoch 38/70
# 128/128 [==============================] - 8s 60ms/step - loss: 0.1600 - accuracy: 0.9344
# Epoch 39/70
# 128/128 [==============================] - 8s 60ms/step - loss: 0.1566 - accuracy: 0.9356
# Epoch 40/70
# 128/128 [==============================] - 8s 60ms/step - loss: 0.1701 - accuracy: 0.9301
# Epoch 41/70
# 128/128 [==============================] - 8s 60ms/step - loss: 0.1521 - accuracy: 0.9371
# Epoch 42/70
# 128/128 [==============================] - 8s 60ms/step - loss: 0.1524 - accuracy: 0.9360
# Epoch 43/70
# 128/128 [==============================] - 8s 60ms/step - loss: 0.1491 - accuracy: 0.9381
# Epoch 44/70
# 128/128 [==============================] - 8s 59ms/step - loss: 0.1397 - accuracy: 0.9438
# Epoch 45/70
# 128/128 [==============================] - 8s 60ms/step - loss: 0.1374 - accuracy: 0.9450
# Epoch 46/70
# 128/128 [==============================] - 8s 60ms/step - loss: 0.1427 - accuracy: 0.9398
# Epoch 47/70
# 128/128 [==============================] - 8s 60ms/step - loss: 0.1415 - accuracy: 0.9441
# Epoch 48/70
# 128/128 [==============================] - 8s 59ms/step - loss: 0.1350 - accuracy: 0.9485
# Epoch 49/70
# 128/128 [==============================] - 8s 60ms/step - loss: 0.1379 - accuracy: 0.9478
# Epoch 50/70
# 128/128 [==============================] - 8s 59ms/step - loss: 0.1368 - accuracy: 0.9449
# Epoch 51/70
# 128/128 [==============================] - 8s 60ms/step - loss: 0.1428 - accuracy: 0.9433
# Epoch 52/70
# 128/128 [==============================] - 8s 60ms/step - loss: 0.1263 - accuracy: 0.9485
# Epoch 53/70
# 128/128 [==============================] - 8s 60ms/step - loss: 0.1360 - accuracy: 0.9449
# Epoch 54/70
# 128/128 [==============================] - 8s 60ms/step - loss: 0.1180 - accuracy: 0.9524
# Epoch 55/70
# 128/128 [==============================] - 8s 60ms/step - loss: 0.1307 - accuracy: 0.9467
# Epoch 56/70
# 128/128 [==============================] - 8s 60ms/step - loss: 0.1252 - accuracy: 0.9513
# Epoch 57/70
# 128/128 [==============================] - 8s 60ms/step - loss: 0.1230 - accuracy: 0.9513
# Epoch 58/70
# 128/128 [==============================] - 8s 60ms/step - loss: 0.1211 - accuracy: 0.9521
# Epoch 59/70
# 128/128 [==============================] - 8s 60ms/step - loss: 0.1183 - accuracy: 0.9515
# Epoch 60/70
# 128/128 [==============================] - 8s 60ms/step - loss: 0.1259 - accuracy: 0.9486
# Epoch 61/70
# 128/128 [==============================] - 8s 60ms/step - loss: 0.1072 - accuracy: 0.9566
# Epoch 62/70
# 128/128 [==============================] - 8s 59ms/step - loss: 0.1114 - accuracy: 0.9559
# Epoch 63/70
# 128/128 [==============================] - 8s 61ms/step - loss: 0.1208 - accuracy: 0.9510
# Epoch 64/70
# 128/128 [==============================] - 8s 60ms/step - loss: 0.1040 - accuracy: 0.9580
# Epoch 65/70
# 128/128 [==============================] - 8s 60ms/step - loss: 0.1072 - accuracy: 0.9577
# Epoch 66/70
# 128/128 [==============================] - 8s 61ms/step - loss: 0.1153 - accuracy: 0.9546
# Epoch 67/70
# 128/128 [==============================] - 8s 61ms/step - loss: 0.1057 - accuracy: 0.9585
# Epoch 68/70
# 128/128 [==============================] - 8s 60ms/step - loss: 0.1068 - accuracy: 0.9581
# Epoch 69/70
# 128/128 [==============================] - 8s 60ms/step - loss: 0.1072 - accuracy: 0.9583
# Epoch 70/70
# 128/128 [==============================] - 8s 61ms/step - loss: 0.0987 - accuracy: 0.9619
# Train loss: 0.1774536219816655
# Train accuracy: 93.37499737739563
# Test loss: 0.6342716356515884
# Test accuracy: 83.95000100135803
# 'model_json = model.to_json()\nwith open("/gdrive/My Drive/Colab Notebooks/dogCat/myMoodModelORIGINAL.json", "w") as json_file:\n    json_file.write(model_json)\n# serialize weights to HDF5\nmodel.save_weights("/gdrive/My Drive/Colab Notebooks/dogCat/model_weightsORIGINAL.h5")\nprint("Saved model to drive")'
